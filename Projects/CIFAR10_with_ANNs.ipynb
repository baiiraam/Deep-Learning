# %% [markdown]
# # CIFAR10

# %%
import tensorflow as tf

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
tf.keras.backend.clear_session()

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=X_train.shape[1:]),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),

    tf.keras.layers.Dense(units=10, activation='softmax')
])

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Nadam(),
    metrics=['accuracy']
)

escb = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=10,
    restore_best_weights=True
)

# %%
history_1 = model.fit(X_train, y_train,
          epochs=20,
          validation_split=0.2,
          callbacks=[escb])
# Out:
# Epoch 1/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 23ms/step - accuracy: 0.1542 - loss: 11.9614 - val_accuracy: 0.2660 - val_loss: 1.9607
# Epoch 2/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - accuracy: 0.2582 - loss: 1.9918 - val_accuracy: 0.2833 - val_loss: 1.9392
# Epoch 3/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - accuracy: 0.2874 - loss: 1.9345 - val_accuracy: 0.3106 - val_loss: 1.8894
# Epoch 4/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 27ms/step - accuracy: 0.3131 - loss: 1.8732 - val_accuracy: 0.3330 - val_loss: 1.8453
# Epoch 5/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 30s 24ms/step - accuracy: 0.3299 - loss: 1.8409 - val_accuracy: 0.3472 - val_loss: 1.8157
# Epoch 6/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 25ms/step - accuracy: 0.3351 - loss: 1.8153 - val_accuracy: 0.3353 - val_loss: 1.8148
# Epoch 7/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 28ms/step - accuracy: 0.3424 - loss: 1.8014 - val_accuracy: 0.3424 - val_loss: 1.7898
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3933 - loss: 1.6716
# [1.6854380369186401, 0.3889999985694885]

# %%
plt.plot(history_1.history['loss'], label='train loss')
plt.plot(history_1.history['val_loss'], label='val loss')
plt.legend()
plt.grid()
plt.show()

# %%
model_2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=X_train.shape[1:]),

    tf.keras.layers.Flatten(),


    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),

    tf.keras.layers.Dense(units=100, activation='swish', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),


    tf.keras.layers.Dense(units=10, activation='softmax')
])

# %%
model_2.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Nadam(),
    metrics=['accuracy']
)

escb_2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=10,
    restore_best_weights=True
)

# %%
history_2 = model_2.fit(
    X_train, y_train,
    epochs=20,
    validation_split=0.2,
    callbacks=[escb_2]
)
# Out:
# Epoch 1/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 48s 19ms/step - accuracy: 0.1680 - loss: 2.3354 - val_accuracy: 0.2250 - val_loss: 2.1106
# Epoch 2/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 46s 23ms/step - accuracy: 0.3056 - loss: 1.9077 - val_accuracy: 0.3443 - val_loss: 1.8399
# Epoch 3/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 35s 18ms/step - accuracy: 0.3473 - loss: 1.8198 - val_accuracy: 0.3220 - val_loss: 1.8670
# Epoch 4/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - accuracy: 0.3681 - loss: 1.7649 - val_accuracy: 0.3253 - val_loss: 1.9107
# Epoch 5/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - accuracy: 0.3899 - loss: 1.7139 - val_accuracy: 0.3232 - val_loss: 2.1369
# Epoch 6/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - accuracy: 0.3960 - loss: 1.6970 - val_accuracy: 0.3743 - val_loss: 2.4627
# Epoch 7/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 49s 24ms/step - accuracy: 0.4056 - loss: 1.6724 - val_accuracy: 0.3936 - val_loss: 2.4366
# Epoch 8/20
# ...

# %%
model_2.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3527 - loss: 1.8185
# [1.8195818662643433, 0.3515999913215637]

# %%
plt.plot(history_2.history['loss'], label='train loss')
plt.plot(history_2.history['val_loss'], label='val loss')
plt.legend()
plt.grid()
plt.show()

# %%
X_train_rescaled = X_train / 255.
X_test_rescaled = X_test / 255.

# %% [markdown]
# Try replacing batch normalization with SELU, and make the necessary adjustments to ensure the network self-normalizes (i.e., standardize the input features, use LeCun normal initialization, make sure the DNN contains only a sequence of dense layers, etc.).

# %%
model_3 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=X_train.shape[1:]),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),

    tf.keras.layers.Dense(units=10, activation='softmax')
])

# %%
model_3.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Nadam(),
    metrics=['accuracy']
)

escb_3 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=10,
    restore_best_weights=True
)

# %%
history_3 = model_3.fit(
    X_train_rescaled, y_train,
    epochs=20,
    validation_split=0.2,
    callbacks=[escb_3]
)
# Out:
# Epoch 1/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 50s 25ms/step - accuracy: 0.1802 - loss: 2.2198 - val_accuracy: 0.2733 - val_loss: 1.9330
# Epoch 2/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 12ms/step - accuracy: 0.2893 - loss: 1.9227 - val_accuracy: 0.2974 - val_loss: 2.0423
# Epoch 3/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 34s 23ms/step - accuracy: 0.3238 - loss: 1.8566 - val_accuracy: 0.3328 - val_loss: 1.8291
# Epoch 4/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 24ms/step - accuracy: 0.3424 - loss: 1.8170 - val_accuracy: 0.2936 - val_loss: 2.0002
# Epoch 5/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - accuracy: 0.3588 - loss: 1.7751 - val_accuracy: 0.3860 - val_loss: 1.7157
# Epoch 6/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 23ms/step - accuracy: 0.3751 - loss: 1.7433 - val_accuracy: 0.3775 - val_loss: 1.7359
# Epoch 7/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - accuracy: 0.3855 - loss: 1.7134 - val_accuracy: 0.3751 - val_loss: 1.7202
# Epoch 8/20
# ...

# %%
plt.plot(history_3.history['loss'], label='train loss')
plt.plot(history_3.history['val_loss'], label='val loss')
plt.legend()
plt.grid()
plt.show()

# %%
loss, accuracy = model_3.evaluate(X_test_rescaled, y_test)

print(f'Test accuracy: {accuracy:.3f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4443 - loss: 1.5826
# Test accuracy: 0.441

# %% [markdown]
# Try regularizing the model with alpha dropout. Then, without retraining your model, see if you can achieve better accuracy using MC dropout.

# %%
model_4 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=X_train.shape[1:]),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=100, activation='selu', kernel_initializer='lecun_normal'),
    tf.keras.layers.Dropout(rate=0.3),

    tf.keras.layers.Dense(units=10, activation='softmax')
])

# %%
model_4.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Nadam(),
    metrics=['accuracy']
)

escb_4 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=10,
    restore_best_weights=True
)

# %%
history_4 = model_4.fit(X_train_rescaled, y_train, epochs=20, validation_split=0.2, callbacks=[escb_4])
# Out:
# Epoch 1/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 58s 26ms/step - accuracy: 0.0974 - loss: 3.2058 - val_accuracy: 0.0997 - val_loss: 2.3262
# Epoch 2/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 24ms/step - accuracy: 0.0988 - loss: 2.3591 - val_accuracy: 0.1003 - val_loss: 2.3123
# Epoch 3/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 25ms/step - accuracy: 0.1001 - loss: 2.3221 - val_accuracy: 0.0980 - val_loss: 2.3030
# Epoch 4/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.1403 - loss: 2.2483 - val_accuracy: 0.1607 - val_loss: 2.1110
# Epoch 5/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.1606 - loss: 2.1584 - val_accuracy: 0.1412 - val_loss: 2.1867
# Epoch 6/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.1690 - loss: 2.1342 - val_accuracy: 0.1722 - val_loss: 2.0858
# Epoch 7/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.1647 - loss: 2.1234 - val_accuracy: 0.1756 - val_loss: 2.1182
# Epoch 8/20
# ...

# %%
model_4.evaluate(X_test_rescaled, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2049 - loss: 2.0641
# [2.062110424041748, 0.19779999554157257]

# %%
plt.plot(history_4.history['loss'], label='train loss')
plt.plot(history_4.history['val_loss'], label='val loss')
plt.legend()
plt.grid()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'1st model accuracy on test data: {accuracy}')
loss, accuracy = model.evaluate(X_test_rescaled, y_test)
print(f'1st model accuracy on rescaled test data: {accuracy}')

print()

loss, accuracy = model_2.evaluate(X_test, y_test)
print(f'2nd model accuracy on test data: {accuracy}')
loss, accuracy = model_2.evaluate(X_test_rescaled, y_test)
print(f'2nd model accuracy on rescaled test data: {accuracy}')

print()

loss, accuracy = model_3.evaluate(X_test, y_test)
print(f'3rd model accuracy on test data: {accuracy}')
loss, accuracy = model_3.evaluate(X_test_rescaled, y_test)
print(f'3rd model accuracy on rescaled test data: {accuracy}')

print()

loss, accuracy = model_4.evaluate(X_test, y_test)
print(f'4th model accuracy on test data: {accuracy}')
loss, accuracy = model_4.evaluate(X_test_rescaled, y_test)
print(f'4th model accuracy on rescaled test data: {accuracy}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3933 - loss: 1.6716
# 1st model accuracy on test data: 0.3889999985694885
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1006 - loss: 3.7807
# 1st model accuracy on rescaled test data: 0.10000000149011612
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3527 - loss: 1.8185
# 2nd model accuracy on test data: 0.3515999913215637
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0715 - loss: 2.6220
# 2nd model accuracy on rescaled test data: 0.07050000131130219
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2670 - loss: 154.9233
# 3rd model accuracy on test data: 0.2632000148296356
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4443 - loss: 1.5826
# 3rd model accuracy on rescaled test data: 0.44130000472068787
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1028 - loss: 2.7936
# 4th model accuracy on test data: 0.10010000318288803
# ...

# %%
histories = [history_1, history_2, history_3, history_4]
for idx, history in enumerate(histories):
  plt.figure(figsize=(12, 6))
  plt.plot(history.history['loss'], label='train loss')
  plt.plot(history.history['val_loss'], label='val loss')
  plt.legend()
  plt.grid()
  plt.title(f'{idx + 1} model learning curve')
  plt.show()
  # print(idx)

# %%
# MC dropout, I don't know what that is. For real.

# %% [markdown]
# ## Try Convolutional Neural Networks
